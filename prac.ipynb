# %%
# eita yatim cell ei cell er sathe uporer cell er kono relation nai.
query = "south korea"
choices = [
    "south korea",
    "korea south",
    "north korea",
    "south africa"
]

process.extract(
    query,
    choices,
    limit=4,
    scorer=fuzz.token_sort_ratio
)
