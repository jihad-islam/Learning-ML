# %%
import numpy as np

# %%
matrix = np.random.randint(1,100, size=(4,4))
matrix
# Out:
# array([[21, 47, 85, 18],
#        [70, 39, 36, 42],
#        [95, 58, 46, 96],
#        [23, 63, 60,  3]])

# %%
matrix[3,2]
# Out:
# np.int64(60)

# %%
matrix[0:2,1:2]
# Out:
# array([[47],
#        [39]])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.eye(2)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
np.ones([3,3])
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.random.randint(10,20, size=[3,3])
# Out:
# array([[17, 15, 12],
#        [13, 10, 12],
#        [16, 12, 19]])
